# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objs as go
from plotly.subplots import make_subplots

# %% [markdown]
# # Load Dataset

# %%
import pandas as pd

file_path = "C:\\Users\\sahud\\Downloads\\P1 DATASET\\Real-time Financial Market Analysis.csv"  
df = pd.read_csv(file_path)

df['date'] = pd.to_datetime(df['date'], format='%d/%m/%Y')

df.set_index('date', inplace=True)

print(df.head())
# Out:
#                spx      dax     ftse    nikkei
# date
# 1994-01-07  469.90  2224.95  3445.98  18124.01
# 1994-01-10  475.27  2225.00  3440.58  18443.44
# 1994-01-11  474.13  2228.10  3413.77  18485.25
# 1994-01-12  474.17  2182.06  3372.02  18793.88
# 1994-01-13  472.47  2142.37  3360.01  18577.26

# %% [markdown]
# # Handle Missing Values

# %%
print(df.isna().sum())
df.fillna(method='ffill', inplace=True)
# Out:
# spx       0
# dax       0
# ftse      0
# nikkei    0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Basic Statistics and Initial Plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print(df.describe())

plt.figure(figsize=(14, 7))
sns.lineplot(data=df[['spx', 'dax', 'ftse', 'nikkei']])
plt.title('Stock Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend(['SPX', 'DAX', 'FTSE', 'NIKKEI'])
plt.grid(True)
plt.show()
# Out:
#                spx           dax         ftse        nikkei
# count  6269.000000   6269.000000  6269.000000   6269.000000
# mean   1288.127542   6080.063363  5422.713545  14597.055700
# std     487.586473   2754.361032  1145.572428   4043.122953
# min     438.920000   1911.700000  2876.600000   7054.980000
# 25%     990.671905   4069.350000  4486.100000  10709.290000
# 50%    1233.420000   5773.340000  5662.430000  15028.170000
# 75%    1459.987747   7443.070000  6304.250000  17860.470000
# max    2872.867839  13559.600000  7778.637689  24124.150000

# %%
import matplotlib.pyplot as plt
df.spx.plot(figsize = (20,10) ,title = 'spx')
# Out:
# <AxesSubplot:title={'center':'spx'}, xlabel='date'>

# %%
df.dax.plot(figsize = (20,10) ,title = 'dax')
# Out:
# <AxesSubplot:title={'center':'dax'}, xlabel='date'>

# %%
df.ftse.plot(figsize = (20,10) ,title = 'ftse')
# Out:
# <AxesSubplot:title={'center':'ftse'}, xlabel='date'>

# %%
df.nikkei.plot(figsize = (20,10) ,title = 'nikkei')
# Out:
# <AxesSubplot:title={'center':'nikkei'}, xlabel='date'>

# %% [markdown]
# # QQ plot

# %%
import scipy.stats
import pylab
scipy.stats.probplot(df.spx,plot =pylab)
# Out:
# ((array([-3.69357572, -3.46171913, -3.33410335, ...,  3.33410335,
#           3.46171913,  3.69357572]),
#   array([ 438.92    ,  441.49    ,  441.96    , ..., 2839.253031,
#          2853.528411, 2872.867839])),
#  (476.46056102841203, 1288.1275420815123, 0.9767273150948816))
